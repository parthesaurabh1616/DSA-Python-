# %% [markdown]
# # 2D Array

# %% [markdown]
# # This are the temperature
#
# - Day 1 - 11, 15, 10, 6
# - Day 2 - 10, 14, 11, 5
# - Day 3 - 12, 17, 12, 8
# - Day 4 - 15, 18, 14, 9

# %% [markdown]
# # Time Complexity : O(m*n) m number of columns and n number of rows.
# # Space Complexity : O(nm)

# %%
import numpy as np

# Create a 2D array

twoDArray = np.array([[11,15,10,6],[10,14,11,5],[12,17,12,8],[15,18,14,9]])
print(twoDArray)
# Out:
# [[11 15 10  6]
#  [10 14 11  5]
#  [12 17 12  8]
#  [15 18 14  9]]
