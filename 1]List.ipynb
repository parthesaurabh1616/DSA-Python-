# %% [markdown]
# # List

# %%
integers = [1,2,3,4]

# %%
print(integers)
# Out:
# [1, 2, 3, 4]

# %%
stringList = ['Milk','Cheese','Butter']
print(stringList)
# Out:
# ['Milk', 'Cheese', 'Butter']

# %%
mixeList = [1,1.5,'spam']
print(mixeList)
# Out:
# [1, 1.5, 'spam']

# %%
nestedList = [1,2,4,5,[1.5,1.6],['test']]
print(nestedList)
# Out:
# [1, 2, 4, 5, [1.5, 1.6], ['test']]

# %%
empty = []
print(empty)
# Out:
# []
